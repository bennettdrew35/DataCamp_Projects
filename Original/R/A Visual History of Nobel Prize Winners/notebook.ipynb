# %% [markdown]
# ## 1. The most Nobel of Prizes
# <p><img style="float: right;margin:5px 20px 5px 1px; max-width:250px" src="https://s3.amazonaws.com/assets.datacamp.com/production/project_309/img/Nobel_Prize.png"></p>
# <p>The Nobel Prize is perhaps the worlds most well known scientific award. Except for the honor, prestige and substantial prize money the recipient also gets a gold medal showing Alfred Nobel (1833 - 1896) who established the prize. Every year it's given to scientists and scholars in the categories chemistry, literature, physics, physiology or medicine, economics, and peace. The first Nobel Prize was handed out in 1901, and at that time the Prize was very Eurocentric and male-focused, but nowadays it's not biased in any way whatsoever. Surely. Right?</p>
# <p>Well, we're going to find out! The Nobel Foundation has made a dataset available of all prize winners from the start of the prize, in 1901, to 2016. Let's load it in and take a look.</p>

# %%
# Loading in required libraries
# .... YOUR CODE FOR TASK 1 ....
library("tidyverse")
# Reading in the Nobel Prize data
nobel <- read_csv('datasets/nobel.csv')

# Taking a look at the first couple of winners
# .... YOUR CODE FOR TASK 1 ....
head(nobel, 200)
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# <U+221A> ggplot2 3.0.0     <U+221A> purrr   0.2.5
# <U+221A> tibble  1.4.2     <U+221A> dplyr   0.7.6
# <U+221A> tidyr   0.8.1     <U+221A> stringr 1.3.1
# <U+221A> readr   1.1.1     <U+221A> forcats 0.3.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
# Parsed with column specification:
# cols(
#   year = col_integer(),
#   category = col_character(),
#   prize = col_character(),
#   motivation = col_character(),
#   prize_share = col_character(),
#   laureate_id = col_integer(),
#   laureate_type = col_character(),
#   full_name = col_character(),
#   birth_date = col_date(format = ""),
#   birth_city = col_character(),
#   birth_country = col_character(),
#   sex = col_character(),
#   organization_name = col_character(),
#   organization_city = col_character(),
#   organization_country = col_character(),
#   death_date = col_date(format = ""),
#   death_city = col_character(),
#   death_country = col_character()
# )
#     year category   prize
# 1   1901 Chemistry  The Nobel Prize in Chemistry 1901
# 2   1901 Literature The Nobel Prize in Literature 1901
# 3   1901 Medicine   The Nobel Prize in Physiology or Medicine 1901
# 4   1901 Peace      The Nobel Peace Prize 1901
# 5   1901 Peace      The Nobel Peace Prize 1901
# 6   1901 Physics    The Nobel Prize in Physics 1901
# 7   1902 Chemistry  The Nobel Prize in Chemistry 1902
# 8   1902 Literature The Nobel Prize in Literature 1902
# 9   1902 Medicine   The Nobel Prize in Physiology or Medicine 1902
# 10  1902 Peace      The Nobel Peace Prize 1902
# 11  1902 Peace      The Nobel Peace Prize 1902
# 12  1902 Physics    The Nobel Prize in Physics 1902
# 13  1902 Physics    The Nobel Prize in Physics 1902
# 14  1903 Chemistry  The Nobel Prize in Chemistry 1903
# 15  1903 Literature The Nobel Prize in Literature 1903
# 16  1903 Medicine   The Nobel Prize in Physiology or Medicine 1903
# 17  1903 Peace      The Nobel Peace Prize 1903
# 18  1903 Physics    The Nobel Prize in Physics 1903
# 19  1903 Physics    The Nobel Prize in Physics 1903
# 20  1903 Physics    The Nobel Prize in Physics 1903
# 21  1904 Chemistry  The Nobel Prize in Chemistry 1904
# 22  1904 Literature The Nobel Prize in Literature 1904
recognition of the extraordinary service they rendered by their researches into the influence of magnetism upon radiation phenomena"
# 13  "in recognition of the extraordinary service they rendered by their researches into the influence of magnetism upon radiation phenomena"
# 14  "in recognition of the extraordinary services he has rendered to the advancement of chemistry by his electrolytic theory of dissociation"
# 15  "as a tribute to his noble, magnificent and versatile poetry, which has always been distinguished by both the freshness of its inspiration and the rare purity of its spirit"
# 16  "in recognition of his contribution to the treatment of diseases, especially lupus vulgaris, with concentrated light radiation, whereby he has opened a new avenue for medical science"
# 17  NA
# 18  "in recognition of the extraordinary services he has rendered by his discovery of spontaneous radioactivity"
# 19  "in recognition of the extraordinary services they have rendered by their joint researches on the radiation phenomena discovered by Professor Henri Becquerel"
# 20  "in recognition of the extraordinary services they have rendered by their joint researches on the radiation phenomena discovered by Professor Henri Becquerel"
# 21  "in recognition of his services in the discovery of the inert gaseous elements in air, and his determination of their place in the periodic system"
# 22  "in recognition of the fresh originality and true inspiration of his poetic production, which faithfully reflects the natural scenery and native spirit of his people, and, in addition, his significant work as a Proven&ccedil;al philologist"
# 23  "in recognition of the numerous and brilliant compositions which, in an individual and original manner, have revived the great traditions of the Spanish drama"
# 24  "in recognition of his work on the physiology of digestion, through which knowledge on vital aspects of the subject has been transformed and enlarged"
# 25  NA
# 26  "for his investigations of the densities of the most important gases and for his discovery of argon in connection with these studies"
# 27  "in recognition of his services in the advancement of organic chemistry and the chemical industry, through his work on organic dyes and hydroaromatic compounds"
# 28  "because of his outstanding merits as an epic writer"
# 29  "for his investigations and discoveries in relation to tuberculosis"
# 30  NA
# ... ...
# 171 "for the discovery of new productive forms of atomic theory"
# 172 "for the discovery of new productive forms of atomic theory"
# 173 "for his discovery of heavy hydrogen"
# 174 "for his bold and ingenious revival of dramatic and scenic art"
# 175 "for their discoveries concerning liver therapy in cases of anaemia"
# 176 "for their discoveries concerning liver therapy in cases of anaemia"
# 177 "for their discoveries concerning liver therapy in cases of anaemia"
# 178 NA
# 179 "in recognition of their synthesis of new radioactive elements"
# 180 "in recognition of their synthesis of new radioactive elements"
# 181 "for his discovery of the organizer effect in embryonic development"
# 182 NA
# 183 "for the discovery of the neutron"
# 184 "for his contributions to our knowledge of molecular structure through his investigations on dipole moments and on the diffraction of X-rays and electrons in gases"
# 185 "for the power, honesty and deep-felt emotions of his dramatic works, which embody an original concept of tragedy"
# 186 "for their discoveries relating to chemical transmission of nerve impulses"
# 187 "for their discoveries relating to chemical transmission of nerve impulses"
# 188 NA
# 189 "for his discovery of cosmic radiation"
# 190 "for his discovery of the positron"
# 191 "for his investigations on carbohydrates and vitamin C"
# 192 "for his investigations on carotenoids, flavins and vitamins A and B2"
# 193 "for the artistic power and truth with which he has depicted human conflict as well as some fundamental aspects of contemporary life in his novel-cycle <I>Les Thibault</I>"
# 194 "for his discoveries in connection with the biological combustion processes, with special reference to vitamin C and the catalysis of fumaric acid"
# 195 NA
# 196 "for their experimental discovery of the diffraction of electrons by crystals"
# 197 "for their experimental discovery of the diffraction of electrons by crystals"
# 198 "for his work on carotenoids and vitamins"
# 199 "for her rich and truly epic descriptions of peasant life in China and for her biographical masterpieces"
# 200 "for the discovery of the role played by the sinus and aortic mechanisms in the regulation of respiration"
#     prize_share laureate_id laureate_type
# 1   1/1         160         Individual
# 2   1/1         569         Individual
# 3   1/1         293         Individual
# 4   1/2         462         Individual
# 5   1/2         463         Individual
# 6   1/1           1         Individual
# 7   1/1         161         Individual
# 8   1/1         571         Individual
# 9   1/1         294         Individual
# 10  1/2         464         Individual
# 11  1/2         465         Individual
# 12  1/2           2         Individual
# 13  1/2           3         Individual
# 14  1/1         162         Individual
# 15  1/1         572         Individual
# 16  1/1         295         Individual
# 17  1/1         466         Individual
# 18  1/2           4         Individual
# 19  1/4           5         Individual
# 20  1/4           6         Individual
# 21  1/1         163         Individual
# 22  1/2         573         Individual
# 23  1/2         574         Individual
# 24  1/1         296         Individual
# 25  1/1         467         Organization
# 26  1/1           8         Individual
# 27  1/1         164         Individual
# 28  1/1         575         Individual
# 29  1/1         297         Individual
# 30  1/1         468         Individual
# ... ...         ...         ...
# 171 1/2          39         Individual
# 172 1/2          40         Individual
# 173 1/1         192         Individual
# 174 1/1         607         Individual
# 175 1/3         326         Individual
# 176 1/3         327         Individual
# 177 1/3         328         Individual
# 178 1/1         499         Individual
# 179 1/2         193         Individual
# 180 1/2         194         Individual
# 181 1/1         329         Individual
# 182 1/1         500         Individual
# 183 1/1          41         Individual
# 184 1/1         195         Individual
# 185 1/1         608         Individual
# 186 1/2         330         Individual
# 187 1/2         331         Individual
# 188 1/1         501         Individual
# 189 1/2          42         Individual
# 190 1/2          43         Individual
# 191 1/2         196         Individual
# 192 1/2         197         Individual
# 193 1/1         609         Individual
# 194 1/1         332         Individual
# 195 1/1         502         Individual
# 196 1/2          44         Individual
# 197 1/2          45         Individual
# 198 1/1         198         Individual
# 199 1/1         610         Individual
# 200 1/1         333         Individual
#     full_name
# 1   Jacobus Henricus van 't Hoff
# 2   Sully Prudhomme
# 3   Emil Adolf von Behring
# 4   Jean Henry Dunant
# 5   Fr<U+00E9>d<U+00E9>ric Passy
# 6   Wilhelm Conrad R<U+00F6>ntgen
# 7   Hermann Emil Fischer
# 8   Christian Matthias Theodor Mommsen
# 9   Ronald Ross
# 10  <U+00C9>lie Ducommun
# 11  Charles Albert Gobat
# 12  Hendrik Antoon Lorentz
# 13  Pieter Zeeman
# 14  Svante August Arrhenius
# 15  Bj<U+00F8>rnstjerne Martinus Bj<U+00F8>rnson
# 16  Niels Ryberg Finsen
# 17  William Randal Cremer
# 18  Antoine Henri Becquerel
# 19  Pierre Curie
# 20  Marie Curie, n<U+00E9>e Sklodowska
# 21  Sir William Ramsay
# 22  Fr<U+00E9>d<U+00E9>ric Mistral
# 23  Jos<U+00E9> Echegaray y Eizaguirre
# 24  Ivan Petrovich Pavlov
# 25  Institut de droit international (Institute of International Law)
# 26  Lord Rayleigh (John William Strutt)
# 27  Johann Friedrich Wilhelm Adolf von Baeyer
# 28  Henryk Sienkiewicz
# 29  Robert Koch
# 30  Baroness Bertha Sophie Felicita von Suttner, n<U+00E9>e Countess Kinsky von Chinic und Tettau
# ... ...
# 171 Erwin Schr<U+00F6>dinger
# 172 Paul Adrien Maurice Dirac
# 193 NA                NA                       1958-08-22 Bell<U+00EA>me
# 194 Szeged            Hungary                  1986-10-22 Woods Hole, MA
# 195 NA                NA                       1958-11-24 Tunbridge Wells
# 196 New York, NY      United States of America 1958-02-01 Charlottesville, VA
# 197 London            United Kingdom           1975-09-10 Cambridge
# 198 Heidelberg        Germany                  1967-07-31 Heidelberg
# 199 NA                NA                       1973-03-06 Danby, VT
# 200 Ghent             Belgium                  1968-07-18 Knokke
#     death_country
# 1   Germany
# 2   France
# 3   Germany
# 4   Switzerland
# 5   France
# 6   Germany
# 7   Germany
# 8   Germany
# 9   United Kingdom
# 10  Switzerland
# 11  Switzerland
# 12  Netherlands
# 13  Netherlands
# 14  Sweden
# 15  France
# 16  Denmark
# 17  United Kingdom
# 18  France
# 19  France
# 20  France
# 21  United Kingdom
# 22  France
# 23  Spain
# 24  Russia
# 25  NA
# 26  United Kingdom
# 27  Germany
# 28  Switzerland
# 29  Germany
# 30  Austria
# ... ...
# 171 Austria
# 172 United States of America
# 173 United States of America
# 174 Italy
# 175 United States of America
# 176 United States of America
# 177 United States of America
# 178 United Kingdom
# 179 France
# 180 France
# 181 Germany
# 182 Germany
# 183 United Kingdom
# 184 United States of America
# 185 United States of America
# 186 United Kingdom
# 187 United States of America
# 188 Argentina
# 189 United States of America
# 190 United States of America
# 191 United Kingdom
# 192 Switzerland
# 193 France
# 194 United States of America
# 195 United Kingdom
# 196 United States of America
# 197 United Kingdom
# 198 West Germany (Germany)
# 199 United States of America
# 200 Belgium

# %% [markdown]
# ## 2. So, who gets the Nobel Prize?
# <p>Just looking at the first couple of prize winners, or Nobel laureates as they are also called, we already see a celebrity: Wilhelm Conrad Röntgen, the guy who discovered X-rays. And actually, we see that all of the winners in 1901 were guys that came from Europe. But that was back in 1901, looking at all winners in the dataset, from 1901 to 2016, which sex and which country is the most commonly represented? </p>
# <p>(For <em>country</em>, we will use the <code>birth_country</code> of the winner, as the <code>organization_country</code> is <code>NA</code> for all shared Nobel Prizes.)</p>

# %%
# Counting the number of (possibly shared) Nobel Prizes handed
# out between 1901 and 2016
nobel %>% filter(!is.na(sex)) %>% count()

# Counting the number of prizes won by male and female recipients.
nobel %>%
    filter(!is.na(sex)) %>% 
    group_by(sex) %>% 
    count()

# Counting the number of prizes won by different nationalities.
nobel %>%
    filter(!is.na(sex)) %>% 
    group_by(birth_country)  %>% 
    count()  %>% 
    arrange(desc(n)) %>% 
    head(20)
# Out:
#   n
# 1 885
#   sex    n
# 1 Female  49
# 2 Male   836
#    birth_country            n
# 1  United States of America 259
# 2  United Kingdom            85
# 3  Germany                   61
# 4  France                    51
# 5  Sweden                    29
# 6  Japan                     24
# 7  Canada                    18
# 8  Netherlands               18
# 9  Italy                     17
# 10 Russia                    17
# 11 Switzerland               16
# 12 Austria                   14
# 13 Norway                    12
# 14 China                     11
# 15 Denmark                   11
# 16 Australia                 10
# 17 Belgium                    9
# 18 Scotland                   9
# 19 South Africa               9
# 20 Germany (Poland)           8

# %% [markdown]
# ## 3. USA dominance
# <p>Not so surprising perhaps: the most common Nobel laureate between 1901 and 2016 was a man born in the United States of America. But in 1901 all the laureates were European. When did the USA start to dominate the Nobel Prize charts?</p>

# %%
# Calculating the proportion of USA born winners per decade
prop_usa_winners <- nobel %>% 
    filter(!is.na(sex)) %>% 
    mutate(usa_born_winner = (birth_country=="United States of America"), decade = (year-year%%10)) %>% 
    group_by(decade) %>% 
    summarize(proportion=(sum(usa_born_winner)/n()))

# Display the proportions of USA born winners per decade
# .... YOUR CODE FOR TASK 3 ....
prop_usa_winners
# Out:
#    decade proportion
# 1  1900   0.01785714
# 2  1910   0.07894737
# 3  1920   0.07407407
# 4  1930   0.25454545
# 5  1940   0.32500000
# 6  1950   0.29577465
# 7  1960   0.28000000
# 8  1970   0.32038835
# 9  1980   0.32978723
# 10 1990   0.41584158
# 11 2000   0.43697479
# 12 2010   0.30379747

# %% [markdown]
# ## 4. USA dominance, visualized
# <p>A table is OK, but to <em>see</em> when the USA started to dominate the Nobel charts we need a plot!</p>

# %%
# Setting the size of plots in this notebook
options(repr.plot.width=7, repr.plot.height=4)

# Plotting USA born winners
# .... YOUR CODE FOR TASK 4 ....
prop_usa_winners %>% 
    ggplot(aes(x = decade, y = proportion)) +
    geom_line() +
    geom_point() +
    scale_y_continuous(limits=c(0,1), labels = scales::percent, expand = expand_scale(0))

# %% [markdown]
# ## 5. What is the gender of a typical Nobel Prize winner?
# <p>So the USA became the dominating winner of the Nobel Prize first in the 1930s and has kept the leading position ever since. But one group that was in the lead from the start, and never seems to let go, are <em>men</em>. Maybe it shouldn't come as a shock that there is some imbalance between how many male and female prize winners there are, but how significant is this imbalance? And is it better or worse within specific prize categories like physics, medicine, literature, etc.?</p>

# %%
# Calculating the proportion of female laureates per decade
prop_female_winners <- nobel %>%
    filter(!is.na(sex)) %>% 
    mutate(female_winner = (sex=="Female"), decade = (year-year%%10)) %>% 
    group_by(decade, category) %>% 
    summarise(proportion = (sum(female_winner)/n()))

# Plotting the proportion of female laureates per decade
# .... YOUR CODE FOR TASK 5 ....
options(repr.plot.width=7, repr.plot.height=4)
prop_female_winners %>% 
    ggplot(aes(x = decade, y = proportion, colour = category)) +
    geom_line() +
    geom_point() +
    scale_y_continuous(limits=c(0,1), labels = scales::percent, expand = expand_scale(0))

# %% [markdown]
# ## 6. The first woman to win the Nobel Prize
# <p>The plot above is a bit messy as the lines are overplotting. But it does show some interesting trends and patterns. Overall the imbalance is pretty large with physics, economics, and chemistry having the largest imbalance. Medicine has a somewhat positive trend, and since the 1990s the literature prize is also now more balanced. The big outlier is the peace prize during the 2010s, but keep in mind that this just covers the years 2010 to 2016.</p>
# <p>Given this imbalance, who was the first woman to receive a Nobel Prize? And in what category?</p>

# %%
# Picking out the first woman to win a Nobel Prize
nobel %>%
    filter(sex=="Female")  %>% 
    top_n(1, desc(year))

# %% [markdown]
# ## 7. Repeat laureates
# <p>For most scientists/writers/activists a Nobel Prize would be the crowning achievement of a long career. But for some people, one is just not enough, and there are few that have gotten it more than once. Who are these lucky few? (Having won no Nobel Prize myself, I'll assume it's just about luck.)</p>

# %%
# Selecting the laureates that have received 2 or more prizes.
nobel %>%
    count(full_name) %>%
    filter(n > 1)

# %% [markdown]
# ## 8. How old are you when you get the prize?
# <p>The list of repeat winners contains some illustrious names! We again meet Marie Curie, who got the prize in physics for discovering radiation and in chemistry for isolating radium and polonium. John Bardeen got it twice in physics for transistors and superconductivity, Frederick Sanger got it twice in chemistry, and Linus Carl Pauling got it first in chemistry and later in peace for his work in promoting nuclear disarmament. We also learn that organizations also get the prize as both the Red Cross and the UNHCR have gotten it twice.</p>
# <p>But how old are you generally when you get the prize?</p>

# %%
# Loading the lubridate package
# .... YOUR CODE FOR TASK 8 ....
library('lubridate')
# Calculating the age of Nobel Prize winners
nobel_age <- nobel %>%
    filter(!is.na(sex)) %>% 
    mutate(age = year - year(birth_date))

# Plotting the age of Nobel Prize winners
# .... YOUR CODE FOR TASK 8 ....
nobel_age %>% 
    ggplot(aes(x=year, y = age)) +
    geom_point() +
    geom_smooth()

# %% [markdown]
# ## 9. Age differences between prize categories
# <p>The plot above shows us a lot! We see that people use to be around 55 when they received the price, but nowadays the average is closer to 65. But there is a large spread in the laureates' ages, and while most are 50+, some are very young.</p>
# <p>We also see that the density of points is much high nowadays than in the early 1900s -- nowadays many more of the prizes are shared, and so there are many more winners. We also see that there was a disruption in awarded prizes around the Second World War (1939 - 1945). </p>
# <p>Let's look at age trends within different prize categories.</p>

# %%
# Same plot as above, but faceted by the category of the Nobel Prize
# .... YOUR CODE FOR TASK 9 ....
ggplot(nobel_age, aes(x = age, y = year)) +
    geom_point() +
    geom_smooth(se = FALSE) +
    facet_wrap(~ category)

# %% [markdown]
# ## 10. Oldest and youngest winners
# <p>Another plot with lots of exciting stuff going on! We see that both winners of the chemistry, medicine, and physics prize have gotten older over time. The trend is strongest for physics: the average age used to be below 50, and now it's almost 70. Literature and economics are more stable, and we also see that economics is a newer category. But peace shows an opposite trend where winners are getting younger! </p>
# <p>In the peace category we also a winner around 2010 that seems exceptionally young. This begs the questions, who are the oldest and youngest people ever to have won a Nobel Prize?</p>

# %%
# The oldest winner of a Nobel Prize as of 2016
nobel_age %>% top_n(1, age)

# The youngest winner of a Nobel Prize as of 2016
nobel_age %>% top_n(1, desc(age))

# %% [markdown]
# ## 11. You get a prize!
# <p><img style="float: right;margin:20px 20px 20px 20px; max-width:200px" src="https://s3.amazonaws.com/assets.datacamp.com/production/project_309/img/paint_nobel_prize.png"></p>
# <p>Hey! You get a prize for making it to the very end of this notebook! It might not be a Nobel Prize, but I made it myself in paint so it should count for something. But don't despair, Leonid Hurwicz was 90 years old when he got his prize, so it might not be too late for you. Who knows.</p>
# <p>Before you leave, what was again the name of the youngest winner ever who in 2014 got the prize for "[her] struggle against the suppression of children and young people and for the right of all children to education"?</p>

# %%
# The name of the youngest winner of the Nobel Prize as of 2016
youngest_winner <- "Malala Yousafzai"
